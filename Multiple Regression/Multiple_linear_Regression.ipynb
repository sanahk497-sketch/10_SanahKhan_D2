# %%
from google.colab import files
files.upload(r'C:\Users\A20405224099\Downloads\Multiple Regression\ultimate_student_productivity_dataset_5000.csv')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import make_regression

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
df = pd.read_csv(r'/content/C:\Users\A20405224099\Downloads\Multiple Regression\ultimate_student_productivity_dataset_5000.csv/ultimate_student_productivity_dataset_5000.csv')
df.head()
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
#    exercise_minutes  caffeine_intake_mg  part_time_job  upcoming_deadline  \
# 0                81                  38              1                  0
# 1               111                 339              0                  0
# 2                68                 266              0                  1
# 3               113                 480              1                  1
# 4               121                  24              1                  0
#
#    internet_quality mental_health_score  focus_index  burnout_level  \
# 0              Good                  10        43.05          31.77
# 1              Good                   3        15.92          37.00
# 2              Good                   8        27.39          34.37
# 3              Poor                   3        22.31          77.31
# 4              Good                   8        38.11          39.53
#
#    productivity_score  exam_score
# 0               73.65       50.16
# 1               13.70        1.00
# 2               45.15       18.30
# 3               20.92        9.37
# 4               59.23       27.81
#
# [5 rows x 21 columns]

# %%
df = pd.DataFrame({'study_hours':X[:,0],'self_study_hours':X[:,1],'exam_score':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    study_hours  self_study_hours  exam_score
# 0    -0.411644         -0.086801  -77.140666
# 1    -0.505772          0.330292  -13.704516
# 2     0.492676          1.487480  127.569147
# 3    -0.442056         -0.481236 -127.422646
# 4     0.968299          0.005545  126.209214

# %%
fig = px.scatter_3d(df, x='study_hours', y='self_study_hours', z='exam_score')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c258654a-2f43-4501-a1e9-5ba2ec8d86f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c258654a-2f43-4501-a1e9-5ba2ec8d86f2")) {                    Plotly.newPlot(                        "c258654a-2f43-4501-a1e9-5ba2ec8d86f2",                        [{"hovertemplate":"study_hours=%{x}\u003cbr\u003eself_study_hours=%{y}\u003cbr\u003eexam_score=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-0.4116440843947815,-0.5057724132551733,0.4926763478649059,-0.44205584031973333,0.9682990154846033,0.26475203234084654,-0.9474513805027088,-1.8887967479821153,2.017653927595698,-0.5617356619549382,-0.19469456103808813,-0.9063205790571676,0.6501762380724064,-0.5858553740589163,0.19889911013191736,-0.4795655948979965,0.32745228687738964,-0.3924044414017781,-1.1335114310808603,-1.125781782000271,-0.6118223235039325,0.32911211791055506,0.09942371017292088,0.989991998155915,0.9251341416098623,-1.5370375886078422,-0.3148475852968061,-0.19303707539473927,-0.13322614390325901,-1.0361436094874832,0.48769131090556667,-0.35350891569241155,-0.7585075463093687,0.6738392310011599,-0.1972895145324363,2.517079756893751,-0.33029000129750435,-2.3262981978054236,1.5841591086053108,-0.14516357329788604,-0.1361230321788226,1.5906149161743517,-1.1366414184059521,-0.5224396368670262,-0.06552213572012582,0.10736325812763507,0.46903666969866736,-1.4914053717996147,-0.5711683645122169,0.03508196085331596,0.49515234045126005,-0.5921429014276757,-0.11994370278095462,0.6358116
866736,-1.4914053717996147,-0.5711683645122169,0.03508196085331596,0.49515234045126005,-0.5921429014276757,-0.11994370278095462,0.6358116769938068,0.7791233399798811,-1.0932696317457389,1.0174468813582633,-0.11949973599032303,0.2576904114063156,-0.5908374453358772,0.8597195969216236,0.33577037089327866,-0.19560370140482325,-0.9321975472928707,-0.21931564187573094,1.8744710787850123,0.049366334861051325,1.0692235936757268,-0.5321244960282067,-0.32628701253742703,-0.35401481795566137,-0.7416507221667147,1.0238394242913325,-1.105847336542628,-0.47055924887504824,0.17944672756616392,-0.7325153753917023,-0.29197885043031285,0.16316749896890204,-1.4510235284911084,-0.8151539685460848,2.323106014381696,0.5125687999173013,0.7804328796482963,1.032470928234825,0.4363918848498108,-1.1535390939446983,0.3397325276575103,-0.413942250628537,-0.5281549692669909,-0.5542746461706598,2.03996310269429,0.4245153726201816,0.09667689069321969,1.8070884650026318,-0.0482185985018863,-0.46948668537487176,-1.0442568631588809,0.2982766366008856,1.2563215613715033],"y":[-0.08680073003303393,0.33029227867309074,1.487479801425626,-0.48123590473289646,0.005545256518627837,0.05606967946754918,-1.4999453005424377,0.10083771758424909,0.22522590294692693,-0.10775799431000152,-0.39197063707852564,-1.1470052240450754,-0.4091535110079094,-0.7184352014011084,-0.023650402309237813,-0.6560302846953846,-0.29827427659687444,-1.0432559634449339,2.3973790561462303,-0.6470467263890889,1.927206176043745,-0.3035440750306136,-1.5752015435709656,0.18282168015958894,0.24030140906864608,1.6151943199037315,0.575522022421466,1.6939603778845425,0.8678337958405062,-1.6053628996335574,-0.06896569752861166,0.6044770250053252,0.027226064542486095,0.31203185744045314,-0.9448762762290521,-0.9658839853454982,0.15504306090766842,-1.6465739079744366,1.4287984824693276,-1.0412168123983918,-1.4655082481073394,-0.5410165805752272,0.21536110219079946,-1.854058799899722,2.4591354095625455,-1.4946373598586022,0.29144869892194647,-0.09225013063544689,-0.2417048003921554,0.10413872364042145,-1.2183087729750244,1.9303342884210626,0.24926909219038257,-0.131748353995504,-2.19333618033268,-0.46036064677999117,-0.4340181723346114,0.0027225328144524306,-1.0414811474975592,-1.2 ...

# %%
lr.coef_
# Out:
# array([60.88675281, 57.25690484])

# %%
lr.intercept_
# Out:
# np.float64(7.250388722099535)

# %% [markdown]
# FROM SCRATCH

# %%
import numpy as np
from sklearn.datasets import load_diabetes

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
X.shape
# Out:
# (442, 10)

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#         60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#        197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#         59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#        237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#        143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#        142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#         77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#         78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#        154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#         71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#        150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#        145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#         94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#         60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#         31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#        114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#        191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#        244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#        263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#         77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#         58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#        140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#        219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#         43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#        140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#         84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#         94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#        220.,  57.])

# %%
y.shape
# Out:
# (442,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (353, 10)
# (89, 10)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
reg.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
reg.intercept_
# Out:
# np.float64(151.88331005254167)

# %%
class MeraLR:

    def __init__(self):
        self.coef_ = None
        self.intercept_ = None

    def fit(self,X_train,y_train):
        X_train = np.insert(X_train,0,1,axis=1)

        # calcuate the coeffs
        betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
        self.intercept_ = betas[0]
        self.coef_ = betas[1:]

    def predict(self,X_test):
        y_pred = np.dot(X_test,self.coef_) + self.intercept_
        return y_pred

# %%
lr = MeraLR()

# %%
lr.fit(X_train,y_train)

# %%
X_train.shape
# Out:
# (353, 10)

# %%
np.insert(X_train,0,1,axis=1).shape
# Out:
# (353, 11)

# %%
y_pred = lr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.43993386615689634

# %%
lr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
lr.intercept_
# Out:
# np.float64(151.88331005254165)
